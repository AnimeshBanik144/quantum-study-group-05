# %% [markdown]
# # Module 1 MCQs
#
# These are based on the 1st two notebooks (Pauli Operators and Standard Gates).

# %% [markdown]
# ## MCQs taken from [this medium blog](https://medium.com/@arkrana9/a-complete-practice-test-for-qiskit-v-2x-certification-8188fc32e78b)
#
# This blog is mentioned on the Google Doc resources list.
#
# Note: Do not refer to the answer key in this blog please. It includes some wrong answers as pointed out by some of the commentors.

# %% [markdown]
# 1) What is the effect of applying an X gate to |1⟩?
#
# A) Produces |0⟩
#
# B) Produces |1⟩
#
# C) Produces (|0⟩ + |1⟩)/√2
#
# D) Produces (|0⟩ − |1⟩)/√2

# %% [markdown]
# 2) Which gate rotates a qubit around the Y-axis?
#
# A) Rx
#
# B) Ry
#
# C) Rz
#
# D) X-gate

# %% [markdown]
# 3) What is the probability of measuring |0⟩ after applying RY(π/2) to |0⟩?
#
# A) 1.0
#
# B) 0.5
#
# C) 0.8536
#
# D) 0.1464

# %% [markdown]
# 4) What is the probability of measuring |1⟩ after applying RX(π/2) to |0⟩?
#
# A) 0.5
#
# B) 0.25
#
# C) 0.75
#
# D) 1

# %% [markdown]
# 5) What is the effect of applying a Hadamard (H) gate to the state |1⟩?
#
# A) |0⟩
#
# B) |1⟩
#
# C) 1/√2 (|0⟩ − |1⟩)
#
# D) 1/√2 (|0⟩ + |1⟩)

# %% [markdown]
# 6) Which Qiskit directive prevents the transpiler from optimizing across a boundary?
#
# A) Measure
#
# B) Reset
#
# C) Barrier
#
# D) Delay

# %% [markdown]
# 7) What stores the result of a measurement in a Qiskit circuit?
#
# A) Quantum register
#
# B) Classical register
#
# C) Qubit
#
# D) Measurement operator

# %% [markdown]
# 8) What is the probability of measuring |0⟩ after applying RY(π/6) to |0⟩?
#
# A) 0.933
#
# B) 0.067
#
# C) 0.5
#
# D) 0.25

# %% [markdown]
# 9) Which instruction in Qiskit prevents gate reordering during optimization?
#
# A) barrier
#
# B) delay
#
# C) snapshot
#
# D) measure

# %% [markdown]
# 10) Which method merges two circuits qc1 and qc2 sequentially?
#
# A) qc1.compose(qc2)
#
# B) qc1.combine(qc2)
#
# C) qc1.draw(qc2)
#
# D) qc1.repeat(qc2)

# %% [markdown]
# ## New MCQs based on previous ones and from the notebook

# %% [markdown]
# 1) What is the Pauli operator represented by Pauli('iXZ')
#
# A) XZ
#
# B) iXZ
#
# C) -iXZ
#
# D) ZX

# %% [markdown]
# 2) In Qiskit Pauli strings, which qubit does the RIGHTMOST character represent?
#
# A) Highest index qubit
#
# B) Lowest index qubit (i.e qubit 0)
#
# C) Middle qubit
#
# D) Depends on system

# %% [markdown]
# 3) Which boolean pair corresponds to Pauli-Y?
#
# A) (z=False, x=True)
#
# B) (z=True, x=False)
#
# C) (z=True, x=True)
#
# D) (z=False, x=False)

# %% [markdown]
# 4) What is the result of:
#
# Pauli('X').compose(Pauli('Y'))
#
# A) Z
#
# B) iZ
#
# C) -iZ
#
# D) Y

# %% [markdown]
# 5) Which statement is TRUE about Pauli operators?
#
# A) They are not unitary
#
# B) They are Hermitian
#
# C) They are non-invertible
#
# D) They change dimension

# %% [markdown]
# 6) What does .anticommutes() check?
#
# A) AB = BA
#
# B) AB = -BA
#
# C) A = B
#
# D) A† = B

# %% [markdown]
# 7) What is the output?
#
# z = [False, True]
#
# x = [True, True]
#
# Pauli((z, x))
#
# A) XY
#
# B) YX
#
# C) ZX
#
# D) YY

# %% [markdown]
# 8) What happens if a circuit used to initialize Pauli contains a CX gate?
#
# A) Works normally
#
# B) Ignores CX
#
# C) Throws error
#
# D) Converts to identity

# %% [markdown]
# 9) What is the matrix dimension of a 3-qubit gate?
#
# A) 3×3
#
# B) 6×6
#
# C) 8×8
#
# D) 2×2

# %% [markdown]
# 10) What is the effect of Reset gate?
#
# A) Measures qubit
#
# B) Sets qubit to |1⟩
#
# C) Sets qubit to |0⟩
#
# D) Deletes qubit

# %% [markdown]
# 11) What is special about global phase?
#
# A) Changes measurement
#
# B) Cannot be observed
#
# C) Changes probabilities

# %% [markdown]
# 12) What determines rotation angle in LinearPauliRotations?
#
# A) Random value
#
# B) slope*x + offset
#
# C) Number of qubits
#
# D) Measurement

# %% [markdown]
# 13) Why prefer Gate/Instruction over QuantumCircuit?
#
# A) Faster execution
#
# B) Better visualization
#
# C) Compiler optimization
#
# D) Less memory

# %% [markdown]
# 14) Which of the following phases is NOT valid for Pauli initialization?
#
# A) i
#
# B) -i
#
# C) -1
#
# D) e^(iπ/3)

# %% [markdown]
# 15)
#
# qc = QuantumCircuit(2)
#
# qc.cx(0,1)
#
# Pauli(qc)
#
# A) Returns CX
#
# B) Returns XX
#
# C) Error
#
# D) Identity
